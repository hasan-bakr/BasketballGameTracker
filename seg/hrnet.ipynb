# %%
import torch
import torchvision.models as models

# Load a pre - trained HRNet model for pose estimation
model = models.get_model('hrnet_w32', pretrained=True)
model.eval()

# Move the model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\524ha\anaconda3\envs\seg\Lib\site-packages\torchvision\models\_api.py:259, in get_model_builder(name)
#     258 try:
# --> 259     fn = BUILTIN_MODELS[name]
#     260 except KeyError:
#
# KeyError: 'hrnet_w32'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       2 import torchvision.models as models
#       4 # Load a pre - trained HRNet model for pose estimation
# ----> 5 model = models.get_model('hrnet_w32', pretrained=True)
#       6 model.eval()
#       8 # Move the model to GPU if available
#
# File c:\Users\524ha\anaconda3\envs\seg\Lib\site-packages\torchvision\models\_api.py:276, in get_model(name, **config)
#     265 def get_model(name: str, **config: Any) -> nn.Module:
#     266     """
#     267     Gets the model name and configuration and returns an instantiated model.
#     268
#    (...)    274         model (nn.Module): The initialized model.
#     275     """
# --> 276     fn = get_model_builder(name)
#     277     return fn(**config)
#
# File c:\Users\524ha\anaconda3\envs\seg\Lib\site-packages\torchvision\models\_api.py:261, in get_model_builder(name)
#     259     fn = BUILTIN_MODELS[name]
#     260 except KeyError:
# --> 261     raise ValueError(f"Unknown model {name}")
#     262 return fn
#
# ValueError: Unknown model hrnet_w32
